# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
depth=np.loadtxt('grid000000000_input_4hii_dummy.ovr')[:,0] #grid 1
depth
# Out:
# array([2.27102e+14, 1.36261e+15, 5.90464e+15, 2.40728e+16, 5.75021e+16,
#        1.00960e+17, 1.57456e+17, 2.30900e+17, 3.26378e+17, 4.47950e+17,
#        5.85868e+17, 7.29303e+17, 8.78475e+17, 1.03361e+18, 1.19496e+18,
#        1.36276e+18, 1.53727e+18, 1.71876e+18, 1.90751e+18, 2.10381e+18,
#        2.30796e+18, 2.52028e+18, 2.74109e+18, 2.97073e+18, 3.20956e+18,
#        3.45794e+18, 3.71626e+18, 3.98491e+18, 4.26431e+18, 4.55488e+18,
#        4.85708e+18, 5.17136e+18, 5.49821e+18, 5.83814e+18, 6.19167e+18,
#        6.55933e+18, 6.94171e+18, 7.33938e+18, 7.75295e+18, 8.18307e+18,
#        8.63039e+18, 9.09561e+18, 9.57943e+18, 1.00826e+19, 1.06059e+19,
#        1.11501e+19, 1.17162e+19, 1.23048e+19, 1.29170e+19, 1.35537e+19,
#        1.42158e+19, 1.49045e+19, 1.56206e+19, 1.63655e+19, 1.71401e+19,
#        1.79457e+19, 1.87835e+19, 1.96548e+19, 2.05610e+19, 2.15035e+19,
#        2.24836e+19, 2.35030e+19, 2.45631e+19, 2.56656e+19, 2.68122e+19,
# ...

# %%
HII=np.loadtxt('grid000000000_input_4hii_dummy.ovr')[:,7]
HII

plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
depth=np.loadtxt('grid000000001_input_4hii_dummy.ovr')[:,0] #grid 1.5
depth
# Out:
# array([4.30576e+13, 2.58345e+14, 1.11950e+15, 4.56410e+15, 1.09022e+16,
#        1.91417e+16, 2.98530e+16, 4.37778e+16, 6.18799e+16, 8.54128e+16,
#        1.16005e+17, 1.55776e+17, 2.07478e+17, 2.74690e+17, 3.62065e+17,
#        4.75654e+17, 6.10653e+17, 7.55079e+17, 9.05282e+17, 1.06149e+18,
#        1.19819e+18, 1.31801e+18, 1.44981e+18, 1.59479e+18, 1.75427e+18,
#        1.92969e+18, 2.12201e+18, 2.32689e+18, 2.53997e+18, 2.76157e+18,
#        2.99203e+18, 3.23171e+18, 3.48098e+18, 3.74022e+18, 4.00983e+18,
#        4.29022e+18, 4.58183e+18, 4.88510e+18, 5.20051e+18, 5.52853e+18,
#        5.86967e+18, 6.22446e+18, 6.59343e+18, 6.97717e+18, 7.37626e+18,
#        7.79131e+18, 8.22296e+18, 8.67188e+18, 9.13876e+18, 9.62431e+18,
#        1.01293e+19, 1.06544e+19, 1.12006e+19, 1.17687e+19, 1.23594e+19,
#        1.29491e+19, 1.35204e+19, 1.41393e+19, 1.47940e+19, 1.54031e+19,
#        1.59777e+19, 1.66307e+19, 1.73340e+19, 1.79493e+19, 1.85014e+19,
# ...

# %%
HII=np.loadtxt('grid000000001_input_4hii_dummy.ovr')[:,7]
HII

plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
depth=np.loadtxt('grid000000002_input_4hii_dummy.ovr')[:,0] #grid 2

HII=np.loadtxt('grid000000002_input_4hii_dummy.ovr')[:,7]


plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
depth=np.loadtxt('grid000000003_input_4hii_dummy.ovr')[:,0] #grid 2.5

HII=np.loadtxt('grid000000003_input_4hii_dummy.ovr')[:,7]


plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
depth=np.loadtxt('grid000000004_input_4hii_dummy.ovr')[:,0] #grid 3

HII=np.loadtxt('grid000000004_input_4hii_dummy.ovr')[:,7]


plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
depth=np.loadtxt('grid000000005_input_4hii_dummy.ovr')[:,0] #grid 3.5

HII=np.loadtxt('grid000000005_input_4hii_dummy.ovr')[:,7]


plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
depth=np.loadtxt('grid000000006_input_4hii_dummy.ovr')[:,0] #grid 4

HII=np.loadtxt('grid000000006_input_4hii_dummy.ovr')[:,7]


plt.plot(depth, HII) 
  
# naming the x axis 
plt.xlabel('depth') 
# naming the y axis 
plt.ylabel('ion-fraction')
# Out:
# Text(0, 0.5, 'ion-fraction')

# %%
density = [1,1.5,2,2.5,3,3.5,4]
size = ['6.5 ', '2.8 ','1.2','0.4', '0.09 ','0.012','0.0013 ']
plt.plot(density,size) 
  
# naming the x axis 
plt.xlabel('gas density ') 
# naming the y axis 
plt.ylabel('Ratio of the size HII/HeII region in cm')
# Out:
# Text(0, 0.5, 'Ratio of the size HII/HeII region in cm')
